# %% [markdown]
# # This notebook will be used for capstone

# %%
import pandas as pd
import numpy as np

print("Hello Capstone Project Course! ");

# %%
#!pip install --user urllib2

from bs4 import BeautifulSoup
import requests
import pandas as pd

#Get the url
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

#get the html
r = requests.get(url)
content = r.text

#Get the table
soup = BeautifulSoup(content)
table = soup.find("table", {"class":"wikitable sortable"})

#Get the headers
th = table.find_all("th")
headers = []
for t in th: 
    headers.append(t.text.replace("\n", ""))
print(headers)

#get the table rows
tableRows = table.find_all("tr")

#for every row in the table rows, if borough is not assigned, remove, if neighbour not assigned, neighbour value = borough
data = []
for row in tableRows: 
    td = row.find_all("td")
    
    
    if(td): 
        if(td[1].text != "Not assigned"): 
            col = []
            i = 0
            borough = ""
            for t in td:
                c = t.text.strip()
                
                if(i == 1): 
                    borough = c
                #if neigbour = not assigned, neighbour = borough
                if(c != "Not assigned"): 
                    col.append(c)
                else: 
                    col.append(borough)
                    
                i = i + 1
            
            data.append(col)


data
# Out:
# ['Postcode', 'Borough', 'Neighbourhood']
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /opt/conda/envs/DSX-Python35/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# [['M3A', 'North York', 'Parkwoods'],
#  ['M4A', 'North York', 'Victoria Village'],
#  ['M5A', 'Downtown Toronto', 'Harbourfront'],
#  ['M5A', 'Downtown Toronto', 'Regent Park'],
#  ['M6A', 'North York', 'Lawrence Heights'],
#  ['M6A', 'North York', 'Lawrence Manor'],
#  ['M7A', "Queen's Park", "Queen's Park"],
#  ['M9A', 'Etobicoke', 'Islington Avenue'],
#  ['M1B', 'Scarborough', 'Rouge'],
#  ['M1B', 'Scarborough', 'Malvern'],
#  ['M3B', 'North York', 'Don Mills North'],
#  ['M4B', 'East York', 'Woodbine Gardens'],
#  ['M4B', 'East York', 'Parkview Hill'],
#  ['M5B', 'Downtown Toronto', 'Ryerson'],
#  ['M5B', 'Downtown Toronto', 'Garden District'],
#  ['M6B', 'North York', 'Glencairn'],
#  ['M9B', 'Etobicoke', 'Cloverdale'],
#  ['M9B', 'Etobicoke', 'Islington'],
#  ['M9B', 'Etobicoke', 'Martin Grove'],
#  ['M9B', 'Etobicoke', 'Princess Gardens'],
#  ['M9B', 'Etobicoke', 'West Deane Park'],
#  ['M1C', 'Scarborough', 'Highland Creek'],
#  ['M1C', 'Scarborough', 'Rouge Hill'],
#  ['M1C', 'Scarborough', 'Port Union'],
#  ['M3C', 'North York', 'Flemingdon Park'],
#  ['M3C', 'North York', 'Don Mills South'],
#  ['M4C', 'East York', 'Woodbine Heights'],
#  ['M5C', 'Downtown Toronto', 'St. James Town'],
#  ['M6C', 'York', 'Humewood-Cedarvale'],
#  ['M9C', 'Etobicoke', 'Bloordale Gardens'],
#  ['M9C', 'Etobicoke', 'Eringate'],
#  ['M9C', 'Etobicoke', 'Markland Wood'],
#  ['M9C', 'Etobicoke', 'Old Burnhamthorpe'],
#  ['M1E', 'Scarborough', 'Guildwood'],
#  ['M1E', 'Scarborough', 'Morningside'],
#  ['M1E', 'Scarborough', 'West Hill'],
#  ['M4E', 'East Toronto', 'The Beaches'],
#  ['M5E', 'Downtown Toronto', 'Berczy Park'],
#  ['M6E', 'York', 'Caledonia-Fairbanks'],
#  ['M1G', 'Scarborough', 'Woburn'],
#  ['M4G', 'East York', 'Leaside'],
#  ['M5G', 'Downtown Toronto', 'Central Bay Street'],
#  ['M6G', 'Downtown Toronto', 'Christie'],
#  ['M1H', 'Scarborough', 'Cedarbrae'],
#  ['M2H', 'North York', 'Hillcrest Village'],
#  ['M3H', 'North York', 'Bathurst Manor'],
#  ['M3H', 'North York', 'Downsview North'],
#  ['M3H', 'North York', 'Wilson Heights'],
#  ['M4H', 'East York', 'Thorncliffe Park'],
#  ['M5H', 'Downtown Toronto', 'Adelaide'],
#  ['M5H', 'Downtown Toronto', 'King'],
#  ['M5H', 'Downtown Toronto', 'Richmond'],
#  ['M6H', 'West Toronto', 'Dovercourt Village'],
#  ['M6H', 'West Toronto', 'Dufferin'],
#  ['M1J', 'Scarborough', 'Scarborough Village'],
#  ['M2J', 'North York', 'Fairview'],
#  ['M2J', 'North York', 'Henry Farm'],
#  ['M2J', 'North York', 'Oriole'],
#  ['M3J', 'North York', 'Northwood Park'],
#  ['M3J', 'North York', 'York University'],
#  ['M4J', 'East York', 'East Toronto'],
#  ['M5J', 'Downtown Toronto', 'Harbourfront East'],
#  ['M5J', 'Downtown Toronto', 'Toronto Islands'],
#  ['M5J', 'Downtown Toronto', 'Union Station'],
#  ['M6J', 'West Toronto', 'Little Portugal'],
#  ['M6J', 'West Toronto', 'Trinity'],
#  ['M1K', 'Scarborough', 'East Birchmount Park'],
#  ['M1K', 'Scarborough', 'Ionview'],
#  ['M1K', 'Scarborough', 'Kennedy Park'],
#  ['M2K', 'North York', 'Bayview Village'],
#  ['M3K', 'North York', 'CFB Toronto'],
#  ['M3K', 'North York', 'Downsview East'],
#  ['M4K', 'East Toronto', 'The Danforth West'],
#  ['M4K', 'East Toronto', 'Riverdale'],
#  ['M5K', 'Downtown Toronto', 'Design Exchange'],
#  ['M5K', 'Downtown Toronto', 'Toronto Dominion Centre'],
#  ['M6K', 'West Toronto', 'Brockton'],
#  ['M6K', 'West Toronto', 'Exhibition Place'],
#  ['M6K', 'West Toronto', 'Parkdale Village'],
#  ['M1L', 'Scarborough', 'Clairlea'],
#  ['M1L', 'Scarborough', 'Golden Mile'],
#  ['M1L', 'Scarborough', 'Oakridge'],
#  ['M2L', 'North York', 'Silver Hills'],
#  ['M2L', 'North York', 'York Mills'],
#  ['M3L', 'North York', 'Downsview West'],
#  ['M4L', 'East Toronto', 'The Beaches West'],
#  ['M4L', 'East Toronto', 'India Bazaar'],
#  ['M5L', 'Downtown Toronto', 'Commerce Court'],
#  ['M5L', 'Downtown Toronto', 'Victoria Hotel'],
#  ['M6L', 'North York', 'Maple Leaf Park'],
#  ['M6L', 'North York', 'North Park'],
#  ['M6L', 'North York', 'Upwood Park'],
#  ['M9L', 'North York', 'Humber Summit'],
#  ['M1M', 'Scarborough', 'Cliffcrest'],
#  ['M1M', 'Scarborough', 'Cliffside'],
#  ['M1M', 'Scarborough', 'Scarborough Village West'],
#  ['M2M', 'North York', 'Newtonbrook'],
#  ['M2M', 'North York', 'Willowdale'],
#  ['M3M', 'North York', 'Downsview Central'],
#  ['M4M', 'East Toronto', 'Studio District'],
#  ['M5M', 'North York', 'Bedford Park'],
#  ['M5M', 'North York', 'Lawrence Manor East'],
#  ['M6M', 'York', 'Del Ray'],
#  ['M6M', 'York', 'Keelesdale'],
#  ['M6M', 'York', 'Mount Dennis'],
#  ['M6M', 'York', 'Silverthorn'],
#  ['M9M', 'North York', 'Emery'],
#  ['M9M', 'North York', 'Humberlea'],
#  ['M1N', 'Scarborough', 'Birch Cliff'],
#  ['M1N', 'Scarborough', 'Cliffside West'],
#  ['M2N', 'North York', 'Willowdale South'],
#  ['M3N', 'North York', 'Downsview Northwest'],
#  ['M4N', 'Central Toronto', 'Lawrence Park'],
#  ['M5N', 'Central Toronto', 'Roselawn'],
#  ['M6N', 'York', 'The Junction North'],
#  ['M6N', 'York', 'Runnymede'],
#  ['M9N', 'York', 'Weston'],
#  ['M1P', 'Scarborough', 'Dorset Park'],
#  ['M1P', 'Scarborough', 'Scarborough Town Centre'],
#  ['M1P', 'Scarborough', 'Wexford Heights'],
#  ['M2P', 'North York', 'York Mills West'],
#  ['M4P', 'Central Toronto', 'Davisville North'],
#  ['M5P', 'Central Toronto', 'Forest Hill North'],
#  ['M5P', 'Central Toronto', 'Forest Hill West'],
#  ['M6P', 'West Toronto', 'High Park'],
#  ['M6P', 'West Toronto', 'The Junction South'],
#  ['M9P', 'Etobicoke', 'Westmount'],
#  ['M1R', 'Scarborough', 'Maryvale'],
#  ['M1R', 'Scarborough', 'Wexford'],
#  ['M2R', 'North York', 'Willowdale West'],
#  ['M4R', 'Central Toronto', 'North Toronto West'],
#  ['M5R', 'Central Toronto', 'The Annex'],
#  ['M5R', 'Central Toronto', 'North Midtown'],
#  ['M5R', 'Central Toronto', 'Yorkville'],
#  ['M6R', 'West Toronto', 'Parkdale'],
#  ['M6R', 'West Toronto', 'Roncesvalles'],
#  ['M7R', 'Mississauga', 'Canada Post Gateway Processing Centre'],
#  ['M9R', 'Etobicoke', 'Kingsview Village'],
#  ['M9R', 'Etobicoke', 'Martin Grove Gardens'],
#  ['M9R', 'Etobicoke', 'Richview Gardens'],
#  ['M9R', 'Etobicoke', 'St. Phillips'],
#  ['M1S', 'Scarborough', 'Agincourt'],
#  ['M4S', 'Central Toronto', 'Davisville'],
#  ['M5S', 'Downtown Toronto', 'Harbord'],
#  ['M5S', 'Downtown Toronto', 'University of Toronto'],
#  ['M6S', 'West Toronto', 'Runnymede'],
#  ['M6S', 'West Toronto', 'Swansea'],
#  ['M1T', 'Scarborough', 'Clarks Corners'],
#  ['M1T', 'Scarborough', 'Sullivan'],
#  ['M1T', 'Scarborough', "Tam O'Shanter"],
#  ['M4T', 'Central Toronto', 'Moore Park'],
#  ['M4T', 'Central Toronto', 'Summerhill East'],
#  ['M5T', 'Downtown Toronto', 'Chinatown'],
#  ['M5T', 'Downtown Toronto', 'Grange Park'],
#  ['M5T', 'Downtown Toronto', 'Kensington Market'],
#  ['M1V', 'Scarborough', 'Agincourt North'],
#  ['M1V', 'Scarborough', "L'Amoreaux East"],
#  ['M1V', 'Scarborough', 'Milliken'],
#  ['M1V', 'Scarborough', 'Steeles East'],
#  ['M4V', 'Central Toronto', 'Deer Park'],
#  ['M4V', 'Central Toronto', 'Forest Hill SE'],
#  ['M4V', 'Central Toronto', 'Rathnelly'],
#  ['M4V', 'Central Toronto', 'South Hill'],
#  ['M4V', 'Central Toronto', 'Summerhill West'],
#  ['M5V', 'Downtown Toronto', 'CN Tower'],
#  ['M5V', 'Downtown Toronto', 'Bathurst Quay'],
#  ['M5V', 'Downtown Toronto', 'Island airport'],
#  ['M5V', 'Downtown Toronto', 'Harbourfront West'],
#  ['M5V', 'Downtown Toronto', 'King and Spadina'],
#  ['M5V', 'Downtown Toronto', 'Railway Lands'],
#  ['M5V', 'Downtown Toronto', 'South Niagara'],
#  ['M8V', 'Etobicoke', 'Humber Bay Shores'],
#  ['M8V', 'Etobicoke', 'Mimico South'],
#  ['M8V', 'Etobicoke', 'New Toronto'],
#  ['M9V', 'Etobicoke', 'Albion Gardens'],
#  ['M9V', 'Etobicoke', 'Beaumond Heights'],
#  ['M9V', 'Etobicoke', 'Humbergate'],
#  ['M9V', 'Etobicoke', 'Jamestown'],
#  ['M9V', 'Etobicoke', 'Mount Olive'],
#  ['M9V', 'Etobicoke', 'Silverstone'],
#  ['M9V', 'Etobicoke', 'South Steeles'],
#  ['M9V', 'Etobicoke', 'Thistletown'],
#  ['M1W', 'Scarborough', "L'Amoreaux West"],
#  ['M1W', 'Scarborough', 'Steeles West'],
#  ['M4W', 'Downtown Toronto', 'Rosedale'],
#  ['M5W', 'Downtown Toronto', 'Stn A PO Boxes 25 The Esplanade'],
#  ['M8W', 'Etobicoke', 'Alderwood'],
#  ['M8W', 'Etobicoke', 'Long Branch'],
#  ['M9W', 'Etobicoke', 'Northwest'],
#  ['M1X', 'Scarborough', 'Upper Rouge'],
#  ['M4X', 'Downtown Toronto', 'Cabbagetown'],
#  ['M4X', 'Downtown Toronto', 'St. James Town'],
#  ['M5X', 'Downtown Toronto', 'First Canadian Place'],
#  ['M5X', 'Downtown Toronto', 'Underground city'],
#  ['M8X', 'Etobicoke', 'The Kingsway'],
#  ['M8X', 'Etobicoke', 'Montgomery Road'],
#  ['M8X', 'Etobicoke', 'Old Mill North'],
#  ['M4Y', 'Downtown Toronto', 'Church and Wellesley'],
#  ['M7Y', 'East Toronto', 'Business reply mail Processing Centre969 Eastern'],
#  ['M8Y', 'Etobicoke', 'Humber Bay'],
#  ['M8Y', 'Etobicoke', "King's Mill Park"],
#  ['M8Y', 'Etobicoke', 'Kingsway Park South East'],
#  ['M8Y', 'Etobicoke', 'Mimico NE'],
#  ['M8Y', 'Etobicoke', 'Old Mill South'],
#  ['M8Y', 'Etobicoke', 'The Queensway East'],
#  ['M8Y', 'Etobicoke', 'Royal York South East'],
#  ['M8Y', 'Etobicoke', 'Sunnylea'],
#  ['M8Z', 'Etobicoke', 'Kingsway Park South West'],
#  ['M8Z', 'Etobicoke', 'Mimico NW'],
#  ['M8Z', 'Etobicoke', 'The Queensway West'],
#  ['M8Z', 'Etobicoke', 'Royal York South West'],
#  ['M8Z', 'Etobicoke', 'South of Bloor']]

# %%
#For one row: combine the neighbour variable when first variable is duplicated
def combine(ro, data): 
    
    for row in data: 
        if (ro[0] == row[0]): 
                if(ro[2] not in row[2]): 
                    row[2] = row[2] + "," + ro[2];
        
    return data  

#All rows: combine neighbour variables when first variable is duplicated
for row in data: 
    data = combine(row, data)

#remove any duplicated values in the combined neighbour variables
for row in data: 
    temp = list(set(row[2].split(",")))
    row[2] = ", ".join(temp)
    
          
#remove duplicated rows based on postcode            
df = pd.DataFrame(data, columns=headers)
df.drop_duplicates(subset='Postcode', keep="first", inplace=True)
df
# Out:
# ['Postcode', 'Borough', 'Neighbourhood']
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /opt/conda/envs/DSX-Python35/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 4        M6A        North York
# 6        M7A      Queen's Park
# 7        M9A         Etobicoke
# 8        M1B       Scarborough
# 10       M3B        North York
# 11       M4B         East York
# 13       M5B  Downtown Toronto
# 15       M6B        North York
# 16       M9B         Etobicoke
# 21       M1C       Scarborough
# 24       M3C        North York
# 26       M4C         East York
# 27       M5C  Downtown Toronto
# 28       M6C              York
# 29       M9C         Etobicoke
# 33       M1E       Scarborough
# 36       M4E      East Toronto
# 37       M5E  Downtown Toronto
# 38       M6E              York
# 39       M1G       Scarborough
# 40       M4G         East York
# 41       M5G  Downtown Toronto
# 42       M6G  Downtown Toronto
# 43       M1H       Scarborough
# 44       M2H        North York
# 45       M3H        North York
# 48       M4H         East York
# ..       ...               ...
# 130      M4R   Central Toronto
# 131      M5R   Central Toronto
# 134      M6R      West Toronto
# 136      M7R       Mississauga
# 137      M9R         Etobicoke
# 141      M1S       Scarborough
# 142      M4S   Central Toronto
# 143      M5S  Downtown Toronto
# 145      M6S      West Toronto
# 147      M1T       Scarborough
# 150      M4T   Central Toronto
# 152      M5T  Downtown Toronto
# 155      M1V       Scarborough
# 159      M4V   Central Toronto
# 164      M5V  Downtown Toronto
# 171      M8V         Etobicoke
# 174      M9V         Etobicoke
# 182      M1W       Scarborough
# 184      M4W  Downtown Toronto
# 185      M5W  Downtown Toronto
# 186      M8W         Etobicoke
# 188      M9W         Etobicoke
# 189      M1X       Scarborough
# 190      M4X  Downtown Toronto
# 192      M5X  Downtown Toronto
# 194      M8X         Etobicoke
# 197      M4Y  Downtown Toronto
# 198      M7Y      East Toronto
# 199      M8Y         Etobicoke
# 207      M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Harbourfront, Regent Park
# 4                     Lawrence Heights, Lawrence Manor
# 6                                         Queen's Park
# 7                                     Islington Avenue
# 8                                       Malvern, Rouge
# 10                                     Don Mills North
# 11                     Woodbine Gardens, Parkview Hill
# 13                            Ryerson, Garden District
# 15                                           Glencairn
# 16   Cloverdale, West Deane Park, Princess Gardens,...
# 21              Port Union, Rouge Hill, Highland Creek
# 24                    Flemingdon Park, Don Mills South
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29   Old Burnhamthorpe, Markland Wood, Eringate, Bl...
# 33                   Morningside, Guildwood, West Hill
# 36                                         The Beaches
# 37                                         Berczy Park
# 38                                 Caledonia-Fairbanks
# 39                                              Woburn
# 40                                             Leaside
# 41                                  Central Bay Street
# 42                                            Christie
# 43                                           Cedarbrae
# 44                                   Hillcrest Village
# 45     Bathurst Manor, Downsview North, Wilson Heights
# 48                                    Thorncliffe Park
# ..                                                 ...
# 130                                 North Toronto West
# 131                Yorkville, North Midtown, The Annex
# 134                             Roncesvalles, Parkdale
# 136              Canada Post Gateway Processing Centre
# 137  St. Phillips, Richview Gardens, Martin Grove G...
# 141                                          Agincourt
# 142                                         Davisville
# 143                     University of Toronto, Harbord
# 145                                 Runnymede, Swansea
# 147            Clarks Corners, Sullivan, Tam O'Shanter
# 150                        Moore Park, Summerhill East
# 152          Chinatown, Kensington Market, Grange Park
# 155  Milliken, Agincourt North, Steeles East, L'Amo...
# 159  South Hill, Rathnelly, Summerhill West, Forest...
# 164  Bathurst Quay, King and Spadina, Island airpor...
# 171       Mimico South, Humber Bay Shores, New Toronto
# 174  Humbergate, Silverstone, Beaumond Heights, Mou...
# 182                      L'Amoreaux West, Steeles West
# 184                                           Rosedale
# 185                    Stn A PO Boxes 25 The Esplanade
# 186                             Long Branch, Alderwood
# 188                                          Northwest
# 189                                        Upper Rouge
# 190                        St. James Town, Cabbagetown
# 192             First Canadian Place, Underground city
# 194      Montgomery Road, The Kingsway, Old Mill North
# 197                               Church and Wellesley
# 198   Business reply mail Processing Centre969 Eastern
# 199  Sunnylea, Mimico NE, King's Mill Park, Royal Y...
# 207  The Queensway West, Mimico NW, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
#The shape of the dataframe

df.shape
# Out:
# (103, 3)

# %%
#!pip install --user geocoder

import geocoder # import geocoder

for row in data: 
    # initialize your variable to None
    lat_lng_coords = None
    

    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(row[0]))
        lat_lng_coords = g.latlng

    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    
    row.append(latitude)
    row.append(longitude)
    
    print(row)
    

data

#remove duplicated rows based on postcode
headers.append("latitude")
headers.append("longitude")
df = pd.DataFrame(data, columns=headers)
df.drop_duplicates(subset='Postcode', keep="first", inplace=True)
df
    
#takes a lot of time

# %%
g = geocoder.google('M4Y, Toronto, Ontario')
print('M4Y', g.latlng)

#takes a lot of time
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-805a03925470> in <module>()
# ----> 1 g = geocoder.google('M4Y, Toronto, Ontario')
#       2 print('M4Y', g.latlng)
#
# ~/.local/lib/python3.5/site-packages/geocoder/api.py in google(location, **kwargs)
#     230         > elevation
#     231     """
# --> 232     return get(location, provider='google', **kwargs)
#     233
#     234
#
# ~/.local/lib/python3.5/site-packages/geocoder/api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# ~/.local/lib/python3.5/site-packages/geocoder/base.py in __init__(self, location, **kwargs)
#     408
#     409         # query and parse results
# --> 410         self._initialize()
#     411
#     412     def __getitem__(self, key):
#
# ~/.local/lib/python3.5/site-packages/geocoder/base.py in _initialize(self)
#     455     def _initialize(self):
#     456         # query URL and get valid JSON (also stored in self.json)
# --> 457         json_response = self._connect()
#     458
#     459         # catch errors
#
# ~/.local/lib/python3.5/site-packages/geocoder/base.py in _connect(self)
#     482                 headers=self.headers,
#     483                 timeout=self.timeout,
# --> 484                 proxies=self.proxies
#     485             )
#     486
#
# ~/.local/lib/python3.5/site-packages/geocoder/google.py in rate_limited_get(self, *args, **kwargs)
#     267             return self.rate_limited_get_for_work(*args, **kwargs)
#     268         else:
# --> 269             return self.rate_limited_get_for_dev(*args, **kwargs)
#     270
#     271     @ratelim.greedy(2500, 60 * 60 * 24)
#
# <decorator-gen-127> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# ~/.local/lib/python3.5/site-packages/ratelim/__init__.py in wrapped_f(self, f, *args, **kwargs)
#      31             time_delta = int(time_delta.total_seconds()) + 1
#      32             if time_delta <= self.__time_interval:
# ---> 33                 time.sleep(self.__time_interval - time_delta + 1)
#      34                 self.__numcalls = 0
#      35                 self.__last_reset = datetime.datetime.now()
#
# KeyboardInterrupt:

# %%
# I used this method

import sys
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_1ff87147f61247d99246b6a446976271 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='YqozYB_MiYiXjgpeiDTGfejypaMfFdu3jdnvylLzIPQF',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_1ff87147f61247d99246b6a446976271.get_object(Bucket='mydatasciencecapstoneproject-donotdelete-pr-1trvxd1omrxgxz',Key='Geospatial_Coordinates (1).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
result = pd.merge(df, df_data_1, how='left', left_on=['Postcode'], right_on = ['Postal Code'])
result = result.drop('Postal Code', 1)
result
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                         Queen's Park  43.662301 -79.389494
# 5                                     Islington Avenue  43.667856 -79.532242
# 6                                       Malvern, Rouge  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                      Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Cloverdale, West Deane Park, Princess Gardens,...  43.650943 -79.554724
# 12              Port Union, Rouge Hill, Highland Creek  43.784535 -79.160497
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Old Burnhamthorpe, Markland Wood, Eringate, Bl...  43.643515 -79.577201
# 18                   Morningside, Guildwood, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 Yorkville, North Midtown, The Annex  43.672710 -79.405678
# 75                              Roncesvalles, Parkdale  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   St. Phillips, Richview Gardens, Martin Grove G...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      University of Toronto, Harbord  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Chinatown, Kensington Market, Grange Park  43.653206 -79.400049
# 85   Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 86   South Hill, Rathnelly, Summerhill West, Forest...  43.686412 -79.400049
# 87   Bathurst Quay, King and Spadina, Island airpor...  43.628947 -79.394420
# 88        Mimico South, Humber Bay Shores, New Toronto  43.605647 -79.501321
# 89   Humbergate, Silverstone, Beaumond Heights, Mou...  43.739416 -79.588437
# 90                       L'Amoreaux West, Steeles West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Long Branch, Alderwood  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         St. James Town, Cabbagetown  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       Montgomery Road, The Kingsway, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100   Business reply mail Processing Centre969 Eastern  43.662744 -79.321558
# 101  Sunnylea, Mimico NE, King's Mill Park, Royal Y...  43.636258 -79.498509
# 102  The Queensway West, Mimico NW, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 20

grouped_clustering = result.drop('Neighbourhood', 1)
grouped_clustering = grouped_clustering.drop('Borough', 1)
grouped_clustering = grouped_clustering.drop('Postcode', 1)


# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

result["clusters"] = kmeans.labels_
result.sort_values(by=["clusters"])


#The top 20 neighbourhood that ar enear each other based on their Latitude and Longitude.
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 7        M3B        North York
# 13       M3C        North York
# 99       M4Y  Downtown Toronto
# 91       M4W  Downtown Toronto
# 86       M4V   Central Toronto
# 83       M4T   Central Toronto
# 80       M5S  Downtown Toronto
# 79       M4S   Central Toronto
# 74       M5R   Central Toronto
# 68       M5P   Central Toronto
# 34       M3J        North York
# 40       M3K        North York
# 10       M6B        North York
# 28       M3H        North York
# 3        M6A        North York
# 65       M1P       Scarborough
# 38       M1K       Scarborough
# 32       M1J       Scarborough
# 71       M1R       Scarborough
# 26       M1H       Scarborough
# 51       M1M       Scarborough
# 5        M9A         Etobicoke
# 11       M9B         Etobicoke
# 76       M7R       Mississauga
# 17       M9C         Etobicoke
# 53       M3M        North York
# 49       M6L        North York
# 46       M3L        North York
# ..       ...               ...
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 20       M5E  Downtown Toronto
# 48       M5L  Downtown Toronto
# 30       M5H  Downtown Toronto
# 2        M5A  Downtown Toronto
# 36       M5J  Downtown Toronto
# 15       M5C  Downtown Toronto
# 31       M6H      West Toronto
# 37       M6J      West Toronto
# 21       M6E              York
# 43       M6K      West Toronto
# 75       M6R      West Toronto
# 16       M6C              York
# 25       M6G  Downtown Toronto
# 94       M9W         Etobicoke
# 70       M9P         Etobicoke
# 64       M9N              York
# 77       M9R         Etobicoke
# 57       M9M        North York
# 23       M4G         East York
# 54       M4M      East Toronto
# 41       M4K      East Toronto
# 35       M4J         East York
# 29       M4H         East York
# 88       M8V         Etobicoke
# 93       M8W         Etobicoke
# 102      M8Z         Etobicoke
# 89       M9V         Etobicoke
# 50       M9L        North York
#
#                                          Neighbourhood   Latitude  Longitude  \
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 7                                      Don Mills North  43.745906 -79.352188
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 99                                Church and Wellesley  43.665860 -79.383160
# 91                                            Rosedale  43.679563 -79.377529
# 86   South Hill, Rathnelly, Summerhill West, Forest...  43.686412 -79.400049
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 80                      University of Toronto, Harbord  43.662696 -79.400049
# 79                                          Davisville  43.704324 -79.388790
# 74                 Yorkville, North Midtown, The Annex  43.672710 -79.405678
# 68                 Forest Hill North, Forest Hill West  43.696948 -79.411307
# 34                     York University, Northwood Park  43.767980 -79.487262
# 40                         Downsview East, CFB Toronto  43.737473 -79.464763
# 10                                           Glencairn  43.709577 -79.445073
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 65   Scarborough Town Centre, Wexford Heights, Dors...  43.757410 -79.273304
# 38         Ionview, East Birchmount Park, Kennedy Park  43.727929 -79.262029
# 32                                 Scarborough Village  43.744734 -79.239476
# 71                                   Wexford, Maryvale  43.750072 -79.295849
# 26                                           Cedarbrae  43.773136 -79.239476
# 51     Cliffcrest, Scarborough Village West, Cliffside  43.716316 -79.239476
# 5                                     Islington Avenue  43.667856 -79.532242
# 11   Cloverdale, West Deane Park, Princess Gardens,...  43.650943 -79.554724
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 17   Old Burnhamthorpe, Markland Wood, Eringate, Bl...  43.643515 -79.577201
# 53                                   Downsview Central  43.728496 -79.495697
# 49            Upwood Park, North Park, Maple Leaf Park  43.713756 -79.490074
# 46                                      Downsview West  43.739015 -79.506944
# ..                                                 ...        ...        ...
# 96                         St. James Town, Cabbagetown  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 20                                         Berczy Park  43.644771 -79.373306
# 48                      Victoria Hotel, Commerce Court  43.648198 -79.379817
# 30                            Richmond, King, Adelaide  43.650571 -79.384568
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 36   Toronto Islands, Union Station, Harbourfront East  43.640816 -79.381752
# 15                                      St. James Town  43.651494 -79.375418
# 31                        Dufferin, Dovercourt Village  43.669005 -79.442259
# 37                            Trinity, Little Portugal  43.647927 -79.419750
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 43        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 75                              Roncesvalles, Parkdale  43.648960 -79.456325
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 25                                            Christie  43.669542 -79.422564
# 94                                           Northwest  43.706748 -79.594054
# 70                                           Westmount  43.696319 -79.532242
# 64                                              Weston  43.706876 -79.518188
# 77   St. Phillips, Richview Gardens, Martin Grove G...  43.688905 -79.554724
# 57                                    Humberlea, Emery  43.724766 -79.532242
# 23                                             Leaside  43.709060 -79.363452
# 54                                     Studio District  43.659526 -79.340923
# 41                        Riverdale, The Danforth West  43.679557 -79.352188
# 35                                        East Toronto  43.685347 -79.338106
# 29                                    Thorncliffe Park  43.705369 -79.349372
# 88        Mimico South, Humber Bay Shores, New Toronto  43.605647 -79.501321
# 93                              Long Branch, Alderwood  43.602414 -79.543484
# 102  The Queensway West, Mimico NW, South of Bloor,...  43.628841 -79.520999
# 89   Humbergate, Silverstone, Beaumond Heights, Mou...  43.739416 -79.588437
# 50                                       Humber Summit  43.756303 -79.565963
#
#      clusters
# 0           0
# 1           0
# 7           0
# 13          0
# 99          1
# 91          1
# 86          1
# 83          1
# 80          1
# 79          1
# 74          1
# 68          1
# 34          2
# 40          2
# 10          2
# 28          2
# 3           2
# 65          3
# 38          3
# 32          3
# 71          3
# 26          3
# 51          3
# 5           4
# 11          4
# 76          4
# 17          4
# 53          5
# 49          5
# 46          5
# ..        ...
# 96         13
# 97         13
# 20         13
# 48         13
# 30         13
# 2          13
# 36         13
# 15         13
# 31         14
# 37         14
# 21         14
# 43         14
# 75         14
# 16         14
# 25         14
# 94         15
# 70         16
# 64         16
# 77         16
# 57         16
# 23         17
# 54         17
# 41         17
# 35         17
# 29         17
# 88         18
# 93         18
# 102        18
# 89         19
# 50         19
#
# [103 rows x 6 columns]
